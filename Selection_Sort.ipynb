# %%
import networkx as nx
import matplotlib.pyplot as plt

# Input array
array = list(map(int, input('Enter numbers in array with <space> between them: ').split()))

# Sort the array using selection sort
for i in range(len(array)):
    temp = i
    for j in range(i + 1, len(array)):
        if array[j] < array[temp]:
            temp = j
    array[i], array[temp] = array[temp], array[i]

# Create a graph
G = nx.Graph()

# Add nodes to the graph
for num in array:
    G.add_node(num)

# Add edges to the graph based on adjacency in the sorted array
for i in range(len(array) - 1):
    G.add_edge(array[i], array[i + 1])

# Draw the graph
nx.draw(G, with_labels=True)
plt.show()
# Out:
# Enter numbers in array with <space> between them: 1 4 2 5 6 7 4 6 54 5
